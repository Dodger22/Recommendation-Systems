# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
content_based_data = pickle.load(open("content_based_data.pkl","rb" ))
content_based_similaritiy = pickle.load(open("content_based_similaritiy.pkl","rb" ))
clusters_fixed = pickle.load(open("users_clusters.pkl","rb" ))
movies_df_fixed = pickle.load(open("movies_clusters.pkl","rb" ))

# %%
movies = pd.read_csv(r'C:\Users\mirza\Desktop\dataset\MovieLens-Credits\movies_metadata.csv', 
        encoding = "ISO-8859-1"
    )

movies = movies[movies["id"].apply(lambda x: x.isnumeric())]
movies["id"]= movies["id"].astype(int)
movies.rename(columns = {'id':"itemId"}, inplace = True)

import ast

def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i["name"])
    
    return L
movies["genres"]= movies["genres"].apply(convert)

ratings_data= pd.read_csv(
        r'C:\Users\mirza\Desktop\dataset\MovieLens-Credits\ratings.csv',
        encoding = "ISO-8859-1",
        header = 0,
        names=["userId", "itemId", "rating", 'timestamp']
    )
ratings_data = pd.merge(ratings_data[["userId","itemId","rating"]], movies[["itemId","genres", "title"]], how="inner", on="itemId")

#ratings = ratings_data[["userId","itemId", "rating"]]

#ratings = ratings[ratings["rating"]==5]

ratings_data = ratings_data[ratings_data["rating"]>=4]
ratings_data
# Out:
# C:\Users\mirza\AppData\Local\Temp\ipykernel_5832\1251067961.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv(r'C:\Users\mirza\Desktop\dataset\MovieLens-Credits\movies_metadata.csv',
#           userId  itemId  rating                      genres  \
# 2             22     110     5.0   [Drama, Mystery, Romance]
# 3             24     110     5.0   [Drama, Mystery, Romance]
# 5             30     110     5.0   [Drama, Mystery, Romance]
# 7             34     110     5.0   [Drama, Mystery, Romance]
# 8             49     110     4.0   [Drama, Mystery, Romance]
# ...          ...     ...     ...                         ...
# 11437608  259266  173153     5.0           [TV Movie, Drama]
# 11437612  263655  172469     4.5                    [Comedy]
# 11437616  270441  166874     4.0  [Crime, Mystery, Thriller]
# 11437622  268239  124091     4.0             [Comedy, Drama]
# 11437635  270694  165159     4.0                          []
#
#                                                      title
# 2                                        Three Colors: Red
# 3                                        Three Colors: Red
# 5                                        Three Colors: Red
# 7                                        Three Colors: Red
# 8                                        Three Colors: Red
# ...                                                    ...
# 11437608                                      Phil Spector
# 11437612                                    Love & Air Sex
# 11437616                                       Coincidence
# 11437622                       The Legend of Kaspar Hauser
# 11437635  Agenzia Riccardo Finzi... praticamente detective
#
# [5748571 rows x 5 columns]

# %%
def reccomend(userıd):
    user = clusters_fixed[clusters_fixed["userId"]==userıd].Cluster.unique() # I found in which cluster User Id 196718 is in
    user_movies = list(movies_df_fixed[int(user)][:15].sample(5).title) # I chose random 5 sample movies in that clsuter
    
    for movie in user_movies:
        movie_index = content_based_data[content_based_data['title'] == movie].index[0]
        distances = content_based_similaritiy[movie_index]
        movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:3] # I recommend 2 movies for per random sample movies
        
        for i in movies_list:
            print(content_based_data.iloc[i[0]].title, content_based_data.iloc[i[0]].genres)

# %%
reccomend(257129)
# Out:
# Police Story 3: Supercop ['Action', 'Crime', 'Thriller']
# Hard Boiled ['Action', 'Thriller', 'Crime']
# I Got the Hook Up ['Action', 'Comedy']
# The Golden Child ['Action', 'Adventure', 'Comedy']
# Night Shift ['Comedy']
# Erik the Viking ['Adventure', 'Fantasy', 'Comedy']
# Jurassic Park ['Adventure', 'Science Fiction']
# The Wild Bunch ['Adventure', 'Western']
# Macross Plus: Movie Edition ['Action', 'Adventure', 'Animation', 'Science Fiction']
# Star Wars: Episode III - Revenge of the Sith ['Science Fiction', 'Adventure', 'Action']

# %%
ratings_data[(ratings_data["userId"]==257129) & (ratings_data["rating"]==5) ]
# Out:
#          userId  itemId  rating  \
# 228129   257129    2762     5.0
# 547932   257129     260     5.0
# 638836   257129     628     5.0
# 1303818  257129    3578     5.0
# 1329588  257129    4896     5.0
# 1417056  257129     296     5.0
# 1705784  257129    4993     5.0
# 1749171  257129    5816     5.0
# 2341148  257129    5064     5.0
# 3021395  257129     588     5.0
# 3208851  257129     593     5.0
# 3635243  257129    4995     5.0
# 5724808  257129    1566     5.0
# 5886948  257129    6283     5.0
# 6880671  257129    2011     5.0
# 6904742  257129    2012     5.0
# 6964452  257129    2115     5.0
# 8424531  257129    6593     5.0
# 9277052  257129      22     5.0
# 9598179  257129    8970     5.0
#
#                                                     genres  \
# 228129                                      [Drama, Crime]
# 547932                         [Action, Thriller, Mystery]
# 638836                                   [Horror, Romance]
# 1303818                                  [Science Fiction]
# 1329588                                    [Comedy, Drama]
# 1417056                [Action, Thriller, Science Fiction]
# 1705784                        [Action, Western, Thriller]
# 1749171                                           [Comedy]
# 2341148                                           [Comedy]
# 3021395                                  [Horror, Mystery]
# 3208851       [Drama, Science Fiction, Adventure, Mystery]
# 3635243                                            [Drama]
# 5724808                              [Drama, History, War]
# 5886948                                   [Comedy, Family]
# 6880671                                 [Animation, Drama]
# 6904742                                            [Drama]
# 6964452                                     [Music, Drama]
# 8424531  [Action, Drama, Fantasy, Foreign, Science Fict...
# 9277052                       [Adventure, Fantasy, Action]
# 9598179                                           [Comedy]
#
#                                                      title
# 228129                                  Young and Innocent
# 547932                                        The 39 Steps
# 638836                          Interview with the Vampire
# 1303818                                         The Tunnel
# 1329588                                  MuxmÃ¤uschenstill
# 1417056                 Terminator 3: Rise of the Machines
# 1705784                                        5 Card Stud
# 1749171                                             Waiter
# 2341148                                    Carry On Doctor
# 3021395                                        Silent Hill
# 3208851                                            Solaris
# 3635243                                      Boogie Nights
# 5724808                                         The Bridge
# 5886948                                          MouseHunt
# 6880671                                         Persepolis
# 6904742                                       Silent Light
# 6964452                                       Light of Day
# 8424531                      Godzilla vs. Mechagodzilla II
# 9277052  Pirates of the Caribbean: The Curse of the Bla...
# 9598179                                 The Out-of-Towners
